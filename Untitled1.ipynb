# %%
# !python3 sentiment_analysis_rev2.py 2
# Out:
# TRAIN AND TEST ON UCI DATASET
# ...
# -------------------- LOGISTIC REGRESSION ------------------------
#
# ------ TRAIN AND TEST ERRORS -------
#
# TRAIN ERROR :  0.9808333333333333
# TEST ERROR :  0.7916666666666666
#
# -------- CONFUSION MATRIX ----------
#
# [[248  47]
#  [ 78 227]]
# ------ CLASSIFICATION REPORT -------
#
#               precision    recall  f1-score   support
#
#            0       0.76      0.84      0.80       295
#            1       0.83      0.74      0.78       305
#
#     accuracy                           0.79       600
#    macro avg       0.79      0.79      0.79       600
# weighted avg       0.80      0.79      0.79       600
#
# -------- ACCURACY SCORE -----------
#
# 0.7916666666666666
# ...
# -------------------- RANDOM FOREST ------------------------
#
# ------ TRAIN AND TEST ERRORS -------
#
# Train error :  0.9975
# Test terror :  0.755
#
# -------- CONFUSION MATRIX ----------
#
# [[248  47]
#  [100 205]]
# ------ CLASSIFICATION REPORT -------
#
# ...

# %%
# !python3 sentiment_analysis_rev2.py 3
# Out:
# TRAIN ON IMDB DATASET AND TEST ON UCI DATASET
# ...
# -------------------- LOGISTIC REGRESSION ------------------------
#
# ------ TRAIN AND TEST ERRORS -------
#
# TRAIN ERROR :  0.93804
# TEST ERROR :  0.5003333333333333
#
# -------- CONFUSION MATRIX ----------
#
# [[752 748]
#  [751 749]]
# ------ CLASSIFICATION REPORT -------
#
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.50      0.50      1500
#          1.0       0.50      0.50      0.50      1500
#
#     accuracy                           0.50      3000
#    macro avg       0.50      0.50      0.50      3000
# weighted avg       0.50      0.50      0.50      3000
#
# -------- ACCURACY SCORE -----------
#
# 0.5003333333333333
# ...
